# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Winnie Simo
# Data Engineer

# %% [markdown]
# *I am interested in data science because it predicts market*

# %% [markdown]
# #### Let calculate a+c in cell 5

# %%
a= 5
c= 6 
a+c
# Out:
# 11

# %% [markdown]
# #### number of list
# Shoes_size = [8, 8.5,9,9.5,10]
# L=len(Shoes_size)
#
# #### image
# ![Passport photo.bmp](attachment:1d99c4f7-b382-4f14-98c9-d84cd52657ec.bmp)
#
#
# #### links
#
# [Click here to Google](https://www.google.com/)
